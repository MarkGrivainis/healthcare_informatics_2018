# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
# CONSTANTS

ROOT_DIR = '/media/mark/Data/deeplesion'
CSV_NAME = 'DL_info.csv'

# %%
# FILE LOADING

df = pd.read_csv(os.path.join(ROOT_DIR, CSV_NAME))

df.head()
# df.tail()["Bounding_boxes"]
# Out:
#               File_name  Patient_index  Study_index  Series_ID  \
# 0  000001_01_01_109.png              1            1          1
# 1  000001_02_01_014.png              1            2          1
# 2  000001_02_01_017.png              1            2          1
# 3  000001_03_01_088.png              1            3          1
# 4  000001_04_01_017.png              1            4          1
#
#    Key_slice_index                            Measurement_coordinates  \
# 0              109  233.537, 95.0204, 234.057, 106.977, 231.169, 1...
# 1               14  224.826, 289.296, 224.016, 305.294, 222.396, 2...
# 2               17  272.323, 320.763, 246.522, 263.371, 234.412, 3...
# 3               88  257.759, 157.618, 260.018, 133.524, 251.735, 1...
# 4               17  304.019, 230.585, 292.217, 211.789, 304.456, 2...
#
#                        Bounding_boxes Lesion_diameters_Pixel_  \
# 0  226.169, 90.0204, 241.252, 111.977        11.9677, 5.10387
# ...

# %%
set(df["Coarse_lesion_type"].values)
# Out:
# {-1, 1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# ## Columns
#
# + File_name
#     + < 000000\_00\_00 > + < \_000 > + .png
#     + \< patient\_id \> + \< key\_slice\_index > + .png
# + Patient_index
#     + NOT SURE
# + Study_index
#     + NOT SURE
# + Series_ID
#     + NOT SURE
# + Key_slice_index
#     + Index of the slide containing the leson
# + Measurement_coordinates
#     + 8 coordinates which define SOME? volume
# + Bounding_boxes
#     + 4 coordinates which define SOME? region
# + Lesion_diameters_Pixel_
#     + 2 values (DEFINES THE DIAMETER?)
# + Normalized_lesion_location
#     + unit x, y, z coordinate of the lesion (CENTER?)
# + Coarse_lesion_type
#     + -1 - 8
# + Possibly_noisy
# + Slice_range
# + Spacing_mm_px_
# + Image_size
# + DICOM_windows
# + Patient_gender
# + Patient_age
# + Train_Val_Test
